# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    doc = nlp(text)

    cleaned_tokens = []

    for token in doc:
        if not token.is_stop and not token.is_punct and token.is_alpha:

            cleaned_tokens.append(token.lemma_.lower())

    return " ".join(cleaned_tokens)

text = "Text preprocessing is essential for Natural Language Processing tasks!"
cleaned_text = preprocess_text(text)
print("Original Text:", text)
print("Processed Text:", cleaned_text)
# Out:
# Original Text: Text preprocessing is essential for Natural Language Processing tasks!
# Processed Text: text preprocessing essential natural language processing task
